# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style="whitegrid")

# %%
df = pd.read_csv("../data/listings.csv")

df.head()
# Out:
#       id                         listing_url       scrape_id last_scraped  \
# 0  21853  https://www.airbnb.com/rooms/21853  20250914152907   2025-09-15
# 1  30320  https://www.airbnb.com/rooms/30320  20250914152907   2025-09-15
# 2  30959  https://www.airbnb.com/rooms/30959  20250914152907   2025-09-15
# 3  40916  https://www.airbnb.com/rooms/40916  20250914152907   2025-09-15
# 4  62423  https://www.airbnb.com/rooms/62423  20250914152907   2025-09-15
#
#             source                                          name  \
# 0  previous scrape                          Bright and airy room
# 1      city scrape                         Apartamentos Dana Sol
# 2  previous scrape               Beautiful loft in Madrid Center
# 3      city scrape                   Apartasol Apartamentos Dana
# 4      city scrape  MAGIC ARTISTIC HOUSE IN THE CENTER OF MADRID
#
#                                          description  \
# 0  We have a quiet and sunny room with a good vie...
# 1                                                NaN
# 2  Beautiful Loft 60m2 size just in the historica...
# 3                                                NaN
# 4  INCREDIBLE HOME OF AN ARTIST SURROUNDED BY PAI...
#
#                                neighborhood_overview  \
# 0  We live in a leafy neighbourhood with plenty o...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  DISTRICT WITH VERY GOOD VIBES IN THE MIDDLE OF...
#
#                                          picture_url  host_id  ...  \
# 0  https://a0.muscache.com/pictures/68483181/87bc...    83531  ...
# 1  https://a0.muscache.com/pictures/336868/f67409...   130907  ...
# 2  https://a0.muscache.com/pictures/78173471/835e...   132883  ...
# 3  https://a0.muscache.com/pictures/hosting/Hosti...   130907  ...
# 4  https://a0.muscache.com/pictures/miso/Hosting-...   303845  ...
#
#   review_scores_communication review_scores_location review_scores_value  \
# 0                        4.82                   4.21                4.67
# 1                        4.78                   4.90                4.69
# 2                        4.63                   4.88                4.25
# 3                        4.81                   4.88                4.59
# 4                        4.86                   4.97                4.60
#
#   license instant_bookable calculated_host_listings_count  \
# 0     NaN                f                              2
# 1     NaN                t                             17
# 2     NaN                f                              1
# 3     NaN                t                             17
# 4     NaN                f                              3
#
#   calculated_host_listings_count_entire_homes  \
# 0                                           0
# 1                                          17
# 2                                           1
# 3                                          17
# 4                                           1
#
#   calculated_host_listings_count_private_rooms  \
# 0                                            2
# 1                                            0
# 2                                            0
# 3                                            0
# 4                                            2
#
#   calculated_host_listings_count_shared_rooms reviews_per_month
# 0                                           0              0.25
# 1                                           0              0.93
# 2                                           0              0.06
# 3                                           0              0.29
# 4                                           0              2.78
#
# [5 rows x 79 columns]

# %%
df.shape
# Out:
# (25000, 79)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25000 entries, 0 to 24999
# Data columns (total 79 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            25000 non-null  int64
#  1   listing_url                                   25000 non-null  object
#  2   scrape_id                                     25000 non-null  int64
#  3   last_scraped                                  25000 non-null  object
#  4   source                                        25000 non-null  object
#  5   name                                          25000 non-null  object
#  6   description                                   24130 non-null  object
#  7   neighborhood_overview                         10586 non-null  object
#  8   picture_url                                   24999 non-null  object
#  9   host_id                                       25000 non-null  int64
#  10  host_url                                      25000 non-null  object
#  11  host_name                                     24903 non-null  object
#  12  host_since                                    24903 non-null  object
#  13  host_location                                 16850 non-null  object
#  14  host_about                                    12598 non-null  object
#  15  host_response_time                            20115 non-null  object
#  16  host_response_rate                            20115 non-null  object
#  17  host_acceptance_rate                          20996 non-null  object
#  18  host_is_superhost                             24332 non-null  object
#  19  host_thumbnail_url                            24903 non-null  object
#  20  host_picture_url                              24903 non-null  object
#  21  host_neighbourhood                            7922 non-null   object
#  22  host_listings_count                           24903 non-null  float64
#  23  host_total_listings_count                     24903 non-null  float64
#  24  host_verifications                            24903 non-null  object
#  25  host_has_profile_pic                          24903 non-null  object
#  26  host_identity_verified                        24903 non-null  object
#  27  neighbourhood                                 10586 non-null  object
#  28  neighbourhood_cleansed                        25000 non-null  object
#  29  neighbourhood_group_cleansed                  25000 non-null  object
#  30  latitude                                      25000 non-null  float64
#  31  longitude                                     25000 non-null  float64
#  32  property_type                                 25000 non-null  object
#  33  room_type                                     25000 non-null  object
#  34  accommodates                                  25000 non-null  int64
#  35  bathrooms                                     18960 non-null  float64
#  36  bathrooms_text                                24972 non-null  object
#  37  bedrooms                                      22488 non-null  float64
#  38  beds                                          18965 non-null  float64
#  39  amenities                                     25000 non-null  object
#  40  price                                         18953 non-null  object
#  41  minimum_nights                                25000 non-null  int64
#  42  maximum_nights                                25000 non-null  int64
#  43  minimum_minimum_nights                        24988 non-null  float64
#  44  maximum_minimum_nights                        24988 non-null  float64
#  45  minimum_maximum_nights                        24988 non-null  float64
#  46  maximum_maximum_nights                        24988 non-null  float64
#  47  minimum_nights_avg_ntm                        25000 non-null  float64
#  48  maximum_nights_avg_ntm                        25000 non-null  float64
#  49  calendar_updated                              0 non-null      float64
#  50  has_availability                              23536 non-null  object
#  51  availability_30                               25000 non-null  int64
#  52  availability_60                               25000 non-null  int64
#  53  availability_90                               25000 non-null  int64
#  54  availability_365                              25000 non-null  int64
#  55  calendar_last_scraped                         25000 non-null  object
#  56  number_of_reviews                             25000 non-null  int64
#  57  number_of_reviews_ltm                         25000 non-null  int64
#  58  number_of_reviews_l30d                        25000 non-null  int64
#  59  availability_eoy                              25000 non-null  int64
#  60  number_of_reviews_ly                          25000 non-null  int64
#  61  estimated_occupancy_l365d                     25000 non-null  int64
#  62  estimated_revenue_l365d                       18953 non-null  float64
#  63  first_review                                  19853 non-null  object
#  64  last_review                                   19853 non-null  object
#  65  review_scores_rating                          19853 non-null  float64
#  66  review_scores_accuracy                        19853 non-null  float64
#  67  review_scores_cleanliness                     19852 non-null  float64
#  68  review_scores_checkin                         19852 non-null  float64
#  69  review_scores_communication                   19853 non-null  float64
#  70  review_scores_location                        19850 non-null  float64
#  71  review_scores_value                           19849 non-null  float64
#  72  license                                       9188 non-null   object
#  73  instant_bookable                              25000 non-null  object
#  74  calculated_host_listings_count                25000 non-null  int64
#  75  calculated_host_listings_count_entire_homes   25000 non-null  int64
#  76  calculated_host_listings_count_private_rooms  25000 non-null  int64
#  77  calculated_host_listings_count_shared_rooms   25000 non-null  int64
#  78  reviews_per_month                             19853 non-null  float64
# dtypes: float64(23), int64(20), object(36)
# memory usage: 15.1+ MB

# %%
df.describe()
# Out:
#                  id     scrape_id       host_id  host_listings_count  \
# count  2.500000e+04  2.500000e+04  2.500000e+04         24903.000000
# mean   7.248274e+17  2.025091e+13  2.806729e+08            63.174477
# std    5.719092e+17  0.000000e+00  2.200065e+08           153.447602
# min    2.185300e+04  2.025091e+13  1.745300e+04             1.000000
# 25%    3.974878e+07  2.025091e+13  6.184860e+07             1.000000
# 50%    9.026240e+17  2.025091e+13  2.542674e+08             5.000000
# 75%    1.237047e+18  2.025091e+13  4.690354e+08            34.000000
# max    1.508659e+18  2.025091e+13  7.184549e+08          1487.000000
#
#        host_total_listings_count      latitude     longitude  accommodates  \
# count               24903.000000  25000.000000  25000.000000  25000.000000
# mean                   75.168454     40.422334     -3.693734      3.169920
# std                   175.195381      0.023665      0.028232      1.921082
# min                     1.000000     40.331400     -3.832060      1.000000
# 25%                     2.000000     40.409670     -3.707486      2.000000
# 50%                     7.000000     40.420827     -3.700850      3.000000
# 75%                    44.000000     40.432819     -3.684085      4.000000
# max                  2767.000000     40.535530     -3.545904     16.000000
#
#           bathrooms      bedrooms  ...  review_scores_cleanliness  \
# count  18960.000000  22488.000000  ...               19852.000000
# mean       1.310021      1.429340  ...                   4.667132
# std        0.704779      0.969122  ...                   0.477303
# min        0.000000      0.000000  ...                   1.000000
# 25%        1.000000      1.000000  ...                   4.580000
# 50%        1.000000      1.000000  ...                   4.800000
# 75%        1.500000      2.000000  ...                   4.940000
# max       19.000000     25.000000  ...                   5.000000
#
#        review_scores_checkin  review_scores_communication  \
# count           19852.000000                 19853.000000
# mean                4.726252                     4.728146
# std                 0.463793                     0.492312
# min                 1.000000                     1.000000
# 25%                 4.680000                     4.700000
# 50%                 4.850000                     4.880000
# 75%                 4.970000                     4.990000
# max                 5.000000                     5.000000
#
#        review_scores_location  review_scores_value  \
# count            19850.000000         19849.000000
# mean                 4.734457             4.533430
# std                  0.399064             0.535482
# min                  1.000000             1.000000
# 25%                  4.650000             4.430000
# 50%                  4.860000             4.660000
# 75%                  4.970000             4.830000
# max                  5.000000             5.000000
#
#        calculated_host_listings_count  \
# count                    25000.000000
# mean                        44.333840
# std                         93.334554
# min                          1.000000
# 25%                          1.000000
# 50%                          4.000000
# 75%                         25.000000
# max                        407.000000
#
#        calculated_host_listings_count_entire_homes  \
# count                                 25000.000000
# mean                                     37.792120
# std                                      90.637266
# min                                       0.000000
# 25%                                       0.000000
# 50%                                       2.000000
# 75%                                      18.000000
# max                                     407.000000
#
#        calculated_host_listings_count_private_rooms  \
# count                                  25000.000000
# mean                                       6.422280
# std                                       26.726249
# min                                        0.000000
# 25%                                        0.000000
# 50%                                        0.000000
# 75%                                        2.000000
# max                                      212.000000
#
#        calculated_host_listings_count_shared_rooms  reviews_per_month
# count                                 25000.000000       19853.000000
# mean                                      0.087200           1.783268
# std                                       1.190014           2.081512
# min                                       0.000000           0.010000
# 25%                                       0.000000           0.340000
# 50%                                       0.000000           1.090000
# 75%                                       0.000000           2.630000
# max                                      29.000000          82.940000
#
# [8 rows x 43 columns]

# %%
columns = [
    "neighbourhood_cleansed",
    "room_type",
    "price",
    "number_of_reviews",
    "availability_365"
]

df = df[columns]

df.head()
# Out:
#   neighbourhood_cleansed        room_type    price  number_of_reviews  \
# 0               Cármenes     Private room      NaN                 33
# 1                    Sol  Entire home/apt  $157.00                173
# 2            Embajadores  Entire home/apt      NaN                  8
# 3            Universidad  Entire home/apt  $143.00                 53
# 4               Justicia     Private room   $65.00                249
#
#    availability_365
# 0               198
# 1               342
# 2                 0
# 3               341
# 4               299

# %%
df.shape
# Out:
# (25000, 5)

# %%
df["price"] = df["price"].replace('[\$,]', '', regex=True).astype(float)

df.head()
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\$'
# <>:1: SyntaxWarning: invalid escape sequence '\$'
# C:\Users\dilso\AppData\Local\Temp\ipykernel_19444\3216651889.py:1: SyntaxWarning: invalid escape sequence '\$'
#   df["price"] = df["price"].replace('[\$,]', '', regex=True).astype(float)
#   neighbourhood_cleansed        room_type  price  number_of_reviews  \
# 0               Cármenes     Private room    NaN                 33
# 1                    Sol  Entire home/apt  157.0                173
# 2            Embajadores  Entire home/apt    NaN                  8
# 3            Universidad  Entire home/apt  143.0                 53
# 4               Justicia     Private room   65.0                249
#
#    availability_365
# 0               198
# 1               342
# 2                 0
# 3               341
# 4               299

# %%
df.dtypes
# Out:
# neighbourhood_cleansed     object
# room_type                  object
# price                     float64
# number_of_reviews           int64
# availability_365            int64
# dtype: object

# %%
neigh_prices = df.groupby("neighbourhood_cleansed")["price"].mean()

neigh_prices.head()
# Out:
# neighbourhood_cleansed
# Abrantes       54.447368
# Acacias       103.862500
# Adelfas       120.785047
# Aeropuerto     93.500000
# Aguilas        63.075000
# Name: price, dtype: float64

# %%
neigh_prices = df.groupby("neighbourhood_cleansed")["price"].mean().sort_values(ascending=False)

neigh_prices.head(10)
# Out:
# neighbourhood_cleansed
# Palomeras Bajas    590.292683
# Fuentelareina      375.800000
# Castillejos        326.032110
# Piovera            301.769231
# Valdefuentes       234.590164
# Sol                233.745471
# Recoletos          228.646388
# Ibiza              227.782222
# Jerónimos          217.988372
# Palacio            210.255219
# Name: price, dtype: float64

# %%
neigh_prices = neigh_prices.round(2)

neigh_prices.head(10)
# Out:
# neighbourhood_cleansed
# Palomeras Bajas    590.29
# Fuentelareina      375.80
# Castillejos        326.03
# Piovera            301.77
# Valdefuentes       234.59
# Sol                233.75
# Recoletos          228.65
# Ibiza              227.78
# Jerónimos          217.99
# Palacio            210.26
# Name: price, dtype: float64

# %%
plt.figure(figsize=(10,6))

neigh_prices.head(10).plot(kind="bar")

plt.title("Top 10 Most Expensive Airbnb Neighborhoods in Madrid")
plt.ylabel("Average Price (€)")
plt.xlabel("Neighborhood")

plt.xticks(rotation=45)

plt.show()

# %%
neigh_prices.head(10).index
# Out:
# Index(['Palomeras Bajas', 'Fuentelareina', 'Castillejos', 'Piovera',
#        'Valdefuentes', 'Sol', 'Recoletos', 'Ibiza', 'Jerónimos', 'Palacio'],
#       dtype='object', name='neighbourhood_cleansed')

# %%
neigh_prices.head(10).values
# Out:
# array([590.29, 375.8 , 326.03, 301.77, 234.59, 233.75, 228.65, 227.78,
#        217.99, 210.26])

# %%
neigh_counts = df["neighbourhood_cleansed"].value_counts()

neigh_counts.head(10)
# Out:
# neighbourhood_cleansed
# Embajadores        2624
# Universidad        2170
# Palacio            1859
# Sol                1293
# Justicia           1227
# Cortes             1057
# Trafalgar           488
# Cuatro Caminos      478
# Palos de Moguer     408
# Goya                404
# Name: count, dtype: int64

# %%
analysis = pd.DataFrame({
    "average_price": neigh_prices,
    "number_of_listings": neigh_counts
})

analysis.head(10)
# Out:
#                         average_price  number_of_listings
# neighbourhood_cleansed
# Abrantes                        54.45                  51
# Acacias                        103.86                 241
# Adelfas                        120.79                 134
# Aeropuerto                      93.50                  13
# Aguilas                         63.08                  57
# Alameda de Osuna                75.40                  30
# Almagro                        153.40                 260
# Almenara                       118.85                 198
# Almendrales                    126.80                 121
# Aluche                          64.67                  88

# %%
analysis_filtered = analysis[analysis["number_of_listings"] > 30]

analysis_filtered.head(10)
# Out:
#                         average_price  number_of_listings
# neighbourhood_cleansed
# Abrantes                        54.45                  51
# Acacias                        103.86                 241
# Adelfas                        120.79                 134
# Aguilas                         63.08                  57
# Almagro                        153.40                 260
# Almenara                       118.85                 198
# Almendrales                    126.80                 121
# Aluche                          64.67                  88
# Apostol Santiago                76.97                  41
# Arapiles                       131.56                 278

# %%
analysis_filtered = analysis_filtered.sort_values("average_price", ascending=False)

analysis_filtered.head(10)
# Out:
#                         average_price  number_of_listings
# neighbourhood_cleansed
# Palomeras Bajas                590.29                  59
# Castillejos                    326.03                 290
# Piovera                        301.77                  37
# Valdefuentes                   234.59                 150
# Sol                            233.75                1293
# Recoletos                      228.65                 320
# Ibiza                          227.78                 284
# Jerónimos                      217.99                 100
# Palacio                        210.26                1859
# Castellana                     208.83                 204

# %%
df_entire = df[df["room_type"] == "Entire home/apt"]

df_entire.head()
# Out:
#   neighbourhood_cleansed        room_type  price  number_of_reviews  \
# 1                    Sol  Entire home/apt  157.0                173
# 2            Embajadores  Entire home/apt    NaN                  8
# 3            Universidad  Entire home/apt  143.0                 53
# 5            Universidad  Entire home/apt    NaN                 64
# 6            Universidad  Entire home/apt  116.0                 36
#
#    availability_365
# 1               342
# 2                 0
# 3               341
# 5                 0
# 6               305

# %%
df_entire = df_entire.dropna(subset=["price"])

df_entire.head()
# Out:
#   neighbourhood_cleansed        room_type  price  number_of_reviews  \
# 1                    Sol  Entire home/apt  157.0                173
# 3            Universidad  Entire home/apt  143.0                 53
# 6            Universidad  Entire home/apt  116.0                 36
# 7            Universidad  Entire home/apt   79.0                 31
# 8            Embajadores  Entire home/apt  300.0                133
#
#    availability_365
# 1               342
# 3               341
# 6               305
# 7               317
# 8               180

# %%
df_entire = df_entire.dropna(subset=["price"])

df_entire.head(10)
# Out:
#    neighbourhood_cleansed        room_type  price  number_of_reviews  \
# 1                     Sol  Entire home/apt  157.0                173
# 3             Universidad  Entire home/apt  143.0                 53
# 6             Universidad  Entire home/apt  116.0                 36
# 7             Universidad  Entire home/apt   79.0                 31
# 8             Embajadores  Entire home/apt  300.0                133
# 11            Embajadores  Entire home/apt  166.0                233
# 21                 Cortes  Entire home/apt  160.0                107
# 22            Universidad  Entire home/apt   98.0                374
# 24            Embajadores  Entire home/apt  117.0                 79
# 26            Embajadores  Entire home/apt   58.0                563
#
#     availability_365
# 1                342
# 3                341
# 6                305
# 7                317
# 8                180
# 11               150
# 21                43
# 22               319
# 24                42
# 26               291

# %%
avg_price_entire = df_entire.groupby("neighbourhood_cleansed")["price"].mean()

avg_price_entire.head()
# Out:
# neighbourhood_cleansed
# Abrantes       81.714286
# Acacias       122.935780
# Adelfas       129.329545
# Aeropuerto    187.333333
# Aguilas       105.285714
# Name: price, dtype: float64

# %%
avg_price_entire = avg_price_entire.round(2)

avg_price_entire.head()
# Out:
# neighbourhood_cleansed
# Abrantes       81.71
# Acacias       122.94
# Adelfas       129.33
# Aeropuerto    187.33
# Aguilas       105.29
# Name: price, dtype: float64

# %%
count_entire = df_entire["neighbourhood_cleansed"].value_counts()

count_entire.head()
# Out:
# neighbourhood_cleansed
# Embajadores    1556
# Universidad    1302
# Palacio        1205
# Sol             859
# Justicia        765
# Name: count, dtype: int64

# %%
final_analysis = pd.DataFrame({
    "average_price_entire_home": avg_price_entire,
    "number_of_entire_homes": count_entire
})

final_analysis.head(10)
# Out:
#                         average_price_entire_home  number_of_entire_homes
# neighbourhood_cleansed
# Abrantes                                    81.71                       7
# Acacias                                    122.94                     109
# Adelfas                                    129.33                      88
# Aeropuerto                                 187.33                       3
# Aguilas                                    105.29                       7
# Alameda de Osuna                           134.75                       4
# Almagro                                    184.45                     126
# Almenara                                   137.04                     122
# Almendrales                                 89.90                      60
# Aluche                                      98.54                      24

# %%
final_filtered = final_analysis[final_analysis["number_of_entire_homes"] > 100]

final_filtered.head(10)
# Out:
#                         average_price_entire_home  number_of_entire_homes
# neighbourhood_cleansed
# Acacias                                    122.94                     109
# Almagro                                    184.45                     126
# Almenara                                   137.04                     122
# Arapiles                                   162.25                     153
# Argüelles                                  249.42                     154
# Bellas Vistas                              125.40                     116
# Berruguete                                 118.76                     147
# Castellana                                 223.72                     145
# Castillejos                                414.60                     164
# Cortes                                     204.14                     707

# %%
final_filtered = final_filtered.sort_values("average_price_entire_home", ascending=False)

final_filtered.head(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 final_filtered = final_filtered.sort_values("average_price_entire_home", ascending=False)
#       3 final_filtered.head(10)
#
# NameError: name 'final_filtered' is not defined
